# %% [markdown]
# <a href="https://colab.research.google.com/github/Sartorio12/Projeto_Modulo_5/blob/main/notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Projeto Final do Módulo VI</center>
# <center> Alguns gastos suspeitos identificados
#
# <center><img src='https://i.imgur.com/QLJaHpa.png' style="width:200px">
#
# <center><a href="https://colab.research.google.com/github/Sartorio12/Projeto_Modulo_5/blob/main/notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Grupo 5:** <a href="https://github.com/LeGuigs" target="_blank">Guilherme Rezende</a> ; <a href="https://github.com/leticiafelippe" target="_blank">Letícia Felippe</a> ; <a href="https://github.com/sartorio12" target="_blank">Mateus Sartorio</a> ; <a href="https://github.com/hara0-tavares" target="_blank">Harão Tavares</a> ; <a href="https://github.com/jonathaslkc" target="_blank">Jonathas Carvalho</a>

# %% [markdown]
# <center><img src='https://i.imgur.com/QadqCNH.jpg' style="width:600px">
# <center>Fonte: Agência Câmara de Notícias — Roque de Sá/Agência Senado

# %% [markdown]
# ---
#
# # **1.** Sobre o estudo e objetivos

# %% [markdown]
# O que você imagina quando ouve o conceito **"Cota Parlamentar"** ou **"Cota para o Exercício da Atividade Parlamentar (CEAP)"**?
#
# Você sabia que é através da **CEAP** que deputados e senadores custeiam suas despesas em atividades parlamentares? O mais interessante disso, é que os dados da CEAP que iremos analisar hoje são abertos e podem ser acessados por qualquer pesso, ou seja, qualquer pessoa pode ver como os deputados e senadores utilizam essse tipo de recurso.
#
# Apesar de cobrir uma quantidade grande de despesas, os gastos com a CEAP devem seguir uma série de regras definidas pelo Ato da Mesa 43/2009. Isso quer dizer que os parlamentares não podem utilizar esses recursos de qualquer maneira. Alguns exemplos de gastos vedados são a aquisição de gêneros alimentícios (ex.: o parlamentar pode gastar com as suas refeições mas não pode comprar carne para o churrasco no fim de semana), gastos de caráter eleitoral e gastos com a participação em cursos de educação básica, graduação e pós-graduação.
#
# Além disso, como citado anteriormente, a CEAP é destinada a custear gastos exclusivamente vinculados ao exercício da atividade parlamentar, o que veda o seu uso para o benefício de terceiros, como por exemplo, o pagamento de refeições para outras pessoas além do próprio parlamentar.
# Apesar de todas essas regras, a fiscalização desses gastos é bastante falha, sendo comum o surgimento de denúncias sobre irregularidades.
#
# Neste cenário surgiu um projeto chamado Operação Serenata de Amor ( https://serenata.ai/ ), que tem como objetivo utilizar ferramentas de ciência de dados para fiscalizar gastos públicos e compartilhar informações relevantes com o público. O projeto tem uma série de módulos. Alguns deles são responsáveis por baixar e limpar os dados, outros por identificar irregularidades e por fim existem alguns módulos responsáveis pela divulgação de eventuais alertas de irregularidades. Um desses módulos de divulgação é o bot @RosieDaSerenata, responsável por publicar alertas de irregularidades no Twitter.
#
# <center><img src='https://i.imgur.com/AjyWlf1.jpg'>

# %% [markdown]
# **É sobre isso que vamos tratar nesta análise, que tem dois focos principais:**
# - *Demonstrar como investigaremos esses dados utilizando Python.*
# - *Elaborar conceitos a respeito da utilização da CEAP nos últimos 3 anos, com destaques no cenário de pandemia(COVID-19).*
#
# #### <center> **Nós do grupo 5 esperamos que a leitura desse notebook seja esclarecedora e útil :)**

# %% [markdown]
# # **2.** Começando a nossa análise

# %% [markdown]
# Essa parte será um pouco teórica, pois nela exibiremos um pouco sobre a limpeza dos dados coletados no site da Câmara. Caso você queira somente acompanhar quais foram as nossas deduções baseadas nessas informações, pode pular para a parte X ( Preciso preencher a parte ).
#
# *Antes de mais nada, vamos apresentar um glossário sobre o DataSet:*
#
# - `Nome Parlamentar(txNomeParlamentar)` :  *Nome adotado pelo Parlamentar ao tomar posse do seu mandato.*
# - `ideCadastro(Identificador Único do Parlamentar)` : *Número que identifica unicamente um deputado federal na CD.*
# - `nuCarteiraParlamentar(Número da Carteira Parlamentar)` : *Documento usado para identificar um deputado federal na CD.*
# - `nuLegislatura(Número da  Legislatura)` : *No contexto da cota CEAP, representa o ano base de início da legislatura.*
# - `sgUF(Sigla da Unidade Federal)` : *Representa a UF do parlamentar.*
# - `sdPartido(Sigla do Partido)` : *Representa o partido do parlamentar.*
# - `codLegislatura(Código da Legislatura)` : *No contexto da cota CEAP, o seu conteúdo representa o código identificador da Legislatura.*
# - `numSubCota(Número da Subcota) `: *Representa o código do Tipo de Despesa, comprovada por meio da emissão de um documento fiscal, a qual é debitada na cota do deputado.*
# - `txtDescricao(Descrição da Subcota)` : *Descrição do Tipo de Despesa.*
# - `numEspecificacaoSubCota(Número da Especificação da Subcota)` : *Representa o código desta especificação mais detalhada.*
# - `txtDescricaoEspecificacao(Descrição da Especificação da Subcota)` : *Detalha o tipo de despesa efetuada.*
# - `txtFornecedor(Fornecedor)` : *Representa o fornecedor do produto ou serviço presente no documento fiscal.*
# - `txtCNPJCPF(CNPJ/CPF)` : *Indica se o fornecedor é CNPJ ou CPF , presente no documento fiscal.*
# - `txtNumero(Número do Documento)` : *Indica o número do documento do emissor da NF em questão.*
# - `indTipoDocumento(Indicativo de Tipo de Documento Fiscal)` : *Tipo de documento do fiscal – 0 para Nota Fiscal; 1 para Recibo; 2 para Despesa no Exterior.*
# - `datEmissao(Data de Emissão)` : *A data de emissão do documento.*
# - `vlrDocumento(Valor do Documento)` : *O seu conteúdo é o valor de face do documento fiscal ou o valor do documento que deu causa à despesa.*
# - `vlrGlosa(Valor da Glosa)` : *Valor da glosa do documento que deu causa à despesa.*
# - `vlrLiquido(Valor Liquido)` : *Valor líquido do documento (será calculado pela diferença entre o Valor do Documento e o Valor da Glosa)*
# - `numMes(Mês) `: *Indica o mês da emissão da nota.*
# - `numAno(Ano) `: *Indica o ano da emissão da nota.*
# - `numParcela(Número da Parcela)` : *O seu conteúdo representa o número da parcela do documento fiscal. Ocorre quando o documento tem de ser reembolsado de forma parcelada.*
# - `txtPassageiro(Nome do Passageiro)` : *O nome do passageiro, em caso da emissão do documento ser uma passagem aérea.*
# - `txtTrecho(Trecho)` : *Representa qual o trecho da viagem, somente em casos de viagem aérea.*
# - `numLote(Número do Lote) `: *Representa a capa do lote em que esse documento será incluído para ser entregue na Câmara para ressarcimento.*
# - `numRessarcimento(Número do Ressarcimento) `: *Indica o ressarcimento do qual o documento faz parte.*
# - `vlrRestituição(Valor da Restituição)` : *Indica o valor que será restituído sobre aquele documento.*
# - `nuDeputadoId(Identificador do Solicitante)` : *Número que identifica um Parlamentar ou Liderança na Transparência da Cota para Exercício da Atividade Parlamentar.*

# %% [markdown]
# ## **2.1.** Materiais e métodos

# %% [markdown]
# O presente trabalho foi desenvolvido utilizando `Google Colaboratory` e `Jupyter Notebook`, com a importação das seguintes bibliotecas:
# > * `Pandas`: é uma biblioteca para uso em Python, open-source e de uso gratuito (sob uma licença BSD), que fornece ferramentas para análise e manipulação de dados. ;<br>
# > * `Numpy`: é uma biblioteca para a linguagem Python com funções para se trabalhar com computação numérica. Seu principal objeto é o vetor n-dimensional, ou ndarray .;<br>
# > * `Matplotlib`: é uma biblioteca com recursos para a geração de gráficos 2D a partir de arrays. Gráficos comuns podem ser criados com alta qualidade a partir de comandos simples, inspirados nos comandos gráficos do MATLAB;<br>
# > * `Seaborn`: é uma biblioteca que atua em cima do matplotlib e ajuda a melhorar o visual dos gráficos, dando uma aparência mais bem acabada; e<br>
# > * `Datetime`: é um módulo que fornece as classes para manipulação de datas e horas. Ainda que a aritmética de data e hora seja suportada, o foco da implementação é na extração eficiente do atributo para formatação da saída e manipulação.
#
# A base de dados pode ser encontrada no site da Câmara ( https://www.camara.leg.br/cota-parlamentar/ ), de acesso livre.
#
# Para versionamento do código utilizamos o `Git` e `GitHub` para publicação do trabalho.
#
# Para organização e acompanhamento das tarefas entre os integrantes do grupo foi utilizado o `Trello`.
#
# As reuniões foram estabelecidas através da plataforma `Discord`.

# %% [markdown]
# # **3.** Importando nossas bibliotecas

# %% [markdown]
# A parte incial, simples importação de bibliotecas que serão utilizadas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## **3.2.** Importando nossos dados

# %%
df1 = pd.read_csv('Ano-2019.csv', sep=';')
df2 = pd.read_csv('Ano-2020.csv', sep=';')
df3 = pd.read_csv('Ano-2021.csv', sep=';')

# %% [markdown]
# ## **3.3.** Começando com limpeza e verificação de dados

# %%
#Concatenando os 3 arquivos em um único
df_unico = pd.concat([df1,df2,df3])

# %%
# Verificando o número de partidos que contém o DataFrame
df_unico.sgPartido.value_counts()
# Out:
# PT               71008
# PSL              67028
# PP               44060
# PL               38495
# MDB              38487
# PSD              36623
# PSB              34907
# PSDB             34371
# REPUBLICANOS     29028
# PDT              28706
# DEM              27015
# PTB              12719
# SOLIDARIEDADE    12350
# PODE             10574
# CIDADANIA         9341
# AVANTE            9257
# PROS              8599
# PSOL              8099
# PCdoB             7288
# PSC               6991
# PATRIOTA          5951
# NOVO              5829
# PV                3761
# PR                1118
# REDE               708
# PRB                531
# S.PART.            377
# PPS                225
# PATRI              154
# PHS                139
# PPL                 20
# Name: sgPartido, dtype: int64

# %%
# Criando uma cópia do dataframe para eventuais imprevistos que possam ocorrer
df_copia = df_unico.copy()

# %%
# Verificando o nome das colunas para facilitar na análise
df_copia.columns
# Out:
# Index(['txNomeParlamentar', 'cpf', 'ideCadastro', 'nuCarteiraParlamentar',
#        'nuLegislatura', 'sgUF', 'sgPartido', 'codLegislatura', 'numSubCota',
#        'txtDescricao', 'numEspecificacaoSubCota', 'txtDescricaoEspecificacao',
#        'txtFornecedor', 'txtCNPJCPF', 'txtNumero', 'indTipoDocumento',
#        'datEmissao', 'vlrDocumento', 'vlrGlosa', 'vlrLiquido', 'numMes',
#        'numAno', 'numParcela', 'txtPassageiro', 'txtTrecho', 'numLote',
#        'numRessarcimento', 'vlrRestituicao', 'nuDeputadoId', 'ideDocumento',
#        'urlDocumento'],
#       dtype='object')

# %%
# Conferindo o tipo de dado em cada coluna
df_copia.dtypes
# Out:
# txNomeParlamentar             object
# cpf                          float64
# ideCadastro                  float64
# nuCarteiraParlamentar        float64
# nuLegislatura                  int64
# sgUF                          object
# sgPartido                     object
# codLegislatura                 int64
# numSubCota                     int64
# txtDescricao                  object
# numEspecificacaoSubCota        int64
# txtDescricaoEspecificacao     object
# txtFornecedor                 object
# txtCNPJCPF                    object
# txtNumero                     object
# indTipoDocumento               int64
# datEmissao                    object
# vlrDocumento                 float64
# vlrGlosa                     float64
# vlrLiquido                   float64
# numMes                         int64
# numAno                         int64
# numParcela                     int64
# txtPassageiro                 object
# txtTrecho                     object
# numLote                        int64
# numRessarcimento             float64
# vlrRestituicao               float64
# nuDeputadoId                   int64
# ideDocumento                   int64
# urlDocumento                  object
# dtype: object

# %%
# Vendo todas as informações e contando os valores não nulos em cada coluna
df_copia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 555500 entries, 0 to 105604
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          555500 non-null  object
#  1   cpf                        553661 non-null  float64
#  2   ideCadastro                553759 non-null  float64
#  3   nuCarteiraParlamentar      553759 non-null  float64
#  4   nuLegislatura              555500 non-null  int64
#  5   sgUF                       553759 non-null  object
#  6   sgPartido                  553759 non-null  object
#  7   codLegislatura             555500 non-null  int64
#  8   numSubCota                 555500 non-null  int64
#  9   txtDescricao               555500 non-null  object
#  10  numEspecificacaoSubCota    555500 non-null  int64
#  11  txtDescricaoEspecificacao  136177 non-null  object
#  12  txtFornecedor              555467 non-null  object
#  13  txtCNPJCPF                 531710 non-null  object
#  14  txtNumero                  555500 non-null  object
#  15  indTipoDocumento           555500 non-null  int64
#  16  datEmissao                 539850 non-null  object
#  17  vlrDocumento               555500 non-null  float64
#  18  vlrGlosa                   555500 non-null  float64
#  19  vlrLiquido                 555500 non-null  float64
#  20  numMes                     555500 non-null  int64
#  21  numAno                     555500 non-null  int64
#  22  numParcela                 555500 non-null  int64
#  23  txtPassageiro              129493 non-null  object
#  24  txtTrecho                  128426 non-null  object
#  25  numLote                    555500 non-null  int64
#  26  numRessarcimento           180842 non-null  float64
#  27  vlrRestituicao             364 non-null     float64
#  28  nuDeputadoId               555500 non-null  int64
#  29  ideDocumento               555500 non-null  int64
#  30  urlDocumento               349639 non-null  object
# dtypes: float64(8), int64(11), object(12)
# memory usage: 135.6+ MB

# %%
# Procurando numero de dados nulos em percentual
round(df_copia.isnull().mean()*100,2)
# Out:
# txNomeParlamentar             0.00
# cpf                           0.33
# ideCadastro                   0.31
# nuCarteiraParlamentar         0.31
# nuLegislatura                 0.00
# sgUF                          0.31
# sgPartido                     0.31
# codLegislatura                0.00
# numSubCota                    0.00
# txtDescricao                  0.00
# numEspecificacaoSubCota       0.00
# txtDescricaoEspecificacao    75.49
# txtFornecedor                 0.01
# txtCNPJCPF                    4.28
# txtNumero                     0.00
# indTipoDocumento              0.00
# datEmissao                    2.82
# vlrDocumento                  0.00
# vlrGlosa                      0.00
# vlrLiquido                    0.00
# numMes                        0.00
# numAno                        0.00
# numParcela                    0.00
# txtPassageiro                76.69
# txtTrecho                    76.88
# numLote                       0.00
# numRessarcimento             67.45
# vlrRestituicao               99.93
# nuDeputadoId                  0.00
# ideDocumento                  0.00
# urlDocumento                 37.06
# dtype: float64

# %%
# o describe foi feito pra destacar os valores negativos presentes nas colunas:'vlrDocumento' e 'vlrLiquido' 
df_copia.describe()
# Out:
#                 cpf    ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# count  5.536610e+05  553759.000000          553759.000000  555500.000000
# mean   3.208493e+10  166015.342644             289.007700    2018.894387
# std    2.921625e+10   45864.510704             153.129661       0.641326
# min    1.608657e+06    4930.000000               1.000000    2015.000000
# 25%    6.197278e+09  141531.000000             160.000000    2019.000000
# 50%    2.227515e+10  178938.000000             292.000000    2019.000000
# 75%    5.098035e+10  204449.000000             424.000000    2019.000000
# max    9.989866e+10  217330.000000             627.000000    2019.000000
#
#        codLegislatura     numSubCota  numEspecificacaoSubCota  \
# count   555500.000000  555500.000000            555500.000000
# mean        55.973597     250.656994                 0.251131
# std          0.160331     412.069770                 0.457949
# min         55.000000       1.000000                 0.000000
# 25%         56.000000       3.000000                 0.000000
# 50%         56.000000      10.000000                 0.000000
# 75%         56.000000     122.000000                 0.000000
# max         56.000000     999.000000                 4.000000
#
#        indTipoDocumento   vlrDocumento       vlrGlosa     vlrLiquido  \
# count     555500.000000  555500.000000  555500.000000  555500.000000
# mean           1.029525     884.412172       3.900387     808.744693
# std            1.567946    2464.526292     139.446699    2464.253989
# min            0.000000   -6605.570000       0.000000   -7821.200000
# 25%            0.000000      63.000000       0.000000      49.510000
# 50%            0.000000     201.380000       0.000000     184.500000
# 75%            1.000000     747.600000       0.000000     642.000000
# max            4.000000  172000.000000   86000.000000  151260.000000
#
#               numMes         numAno     numParcela       numLote  \
# count  555500.000000  555500.000000  555500.000000  5.555000e+05
# mean        6.083879    2019.669870       0.000238  1.130421e+06
# std         3.337029       0.775475       0.015413  7.872364e+05
# min         1.000000    2019.000000       0.000000  0.000000e+00
# 25%         3.000000    2019.000000       0.000000  0.000000e+00
# 50%         6.000000    2019.000000       0.000000  1.620008e+06
# 75%         9.000000    2020.000000       0.000000  1.707915e+06
# max        12.000000    2021.000000       1.000000  1.789366e+06
#
#        numRessarcimento  vlrRestituicao   nuDeputadoId  ideDocumento
# count          180842.0      364.000000  555500.000000  5.555000e+05
# mean                0.0      873.633571    2734.361870  5.045073e+06
# std                 0.0     2367.571616     773.342999  2.865350e+06
# min                 0.0        1.000000      19.000000  0.000000e+00
# 25%                 0.0        6.975000    2265.000000  1.705442e+06
# 50%                 0.0       26.105000    3062.000000  6.888214e+06
# 75%                 0.0      277.395000    3312.000000  7.075930e+06
# max                 0.0    20000.000000    3487.000000  7.245337e+06

# %%
# Essa consulta fizemos um novo df, filtrando na coluna 'txtDescricao' valores diferentes de 'PASSAGEM AÉREA - RPA'  e 'PASSAGEM AÉREA - SIGEPA'
# a partir desse novo df fazer os cálculos de despesas.
valores = df_copia[(df_copia['txtDescricao'] != 'PASSAGEM AÉREA - RPA')&(df_copia['txtDescricao'] != 'PASSAGEM AÉREA - SIGEPA')]
valores['txtDescricao'].unique()
valores.vlrLiquido
# Out:
# 0          111.30
# 1          117.19
# 2          120.15
# 3          151.18
# 4          119.90
#            ...
# 105600    5000.00
# 105601    7000.00
# 105602    4000.00
# 105603       1.10
# 105604       1.08
# Name: vlrLiquido, Length: 427074, dtype: float64

# %%
# os dois valores negativos da coluna 'VrlLiquido'
valores.query('vlrLiquido < 0')['vlrLiquido']
# Out:
# 23210    -868.00
# 28211   -1762.66
# Name: vlrLiquido, dtype: float64

# %%
# Convertemos a coluna datEmissao de object para datatime e colocamos só pra mostrar o formato dia/mes/ano pq o horário é irrelevante para as consultas
df_copia['datEmissao'] = pd.to_datetime(df_copia['datEmissao'], format = '%Y/%m/%d')
df_copia['datEmissao']
# Out:
# 0        2019-01-16
# 1        2019-02-04
# 2        2019-02-25
# 3        2019-03-28
# 4        2019-05-07
#             ...
# 105600   2021-07-28
# 105601   2021-08-11
# 105602   2021-07-29
# 105603          NaT
# 105604          NaT
# Name: datEmissao, Length: 555500, dtype: datetime64[ns]

# %%
#Conferindo se o type da data foi transformado
df_copia.dtypes
# Out:
# txNomeParlamentar                    object
# cpf                                 float64
# ideCadastro                         float64
# nuCarteiraParlamentar               float64
# nuLegislatura                         int64
# sgUF                                 object
# sgPartido                            object
# codLegislatura                        int64
# numSubCota                            int64
# txtDescricao                         object
# numEspecificacaoSubCota               int64
# txtDescricaoEspecificacao            object
# txtFornecedor                        object
# txtCNPJCPF                           object
# txtNumero                            object
# indTipoDocumento                      int64
# datEmissao                   datetime64[ns]
# vlrDocumento                        float64
# vlrGlosa                            float64
# vlrLiquido                          float64
# numMes                                int64
# numAno                                int64
# numParcela                            int64
# txtPassageiro                        object
# txtTrecho                            object
# numLote                               int64
# numRessarcimento                    float64
# vlrRestituicao                      float64
# nuDeputadoId                          int64
# ideDocumento                          int64
# urlDocumento                         object
# dtype: object

# %%
# Verificando o novo tamanho do DataFrame
df_copia.shape
# Out:
# (555500, 31)

# %%
# Aqui estamos procurando por Parlamentares sem estado e sem partido.
sem_partido_sem_uf = valores[valores['sgUF'].isnull()][['txNomeParlamentar', 'sgUF', 'sgPartido','vlrLiquido']]
sem_partido_sem_uf
# Out:
#     txNomeParlamentar sgUF sgPartido  vlrLiquido
# 0          LID.GOV-CD  NaN       NaN      111.30
# 1          LID.GOV-CD  NaN       NaN      117.19
# 2          LID.GOV-CD  NaN       NaN      120.15
# 3          LID.GOV-CD  NaN       NaN      151.18
# 4          LID.GOV-CD  NaN       NaN      119.90
# ..                ...  ...       ...         ...
# 439            LIDMIN  NaN       NaN     4000.00
# 440            LIDMIN  NaN       NaN      137.97
# 441            LIDMIN  NaN       NaN      175.18
# 442            LIDMIN  NaN       NaN     3800.00
# 443            LIDMIN  NaN       NaN     3800.00
#
# [1741 rows x 4 columns]

# %%
#Atribuindo os partidos correspondentes as despesas atribuídas apenas a lideranças
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO PSL", 'PSL', df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO PT", 'PT', df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO PTB", 'PTB', df_copia.sgPartido) 
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO PSDB", 'PSDB', df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO PODEMOS", 'PODEMOS', df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO SOLIDARIEDADE", 'SOLIDARIEDADE', df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO PSD", 'PSD',df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO NOVO", 'NOVO',df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO DEMOCRATAS", 'DEMOCRATAS', df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO CIDADANIA", 'CIDADANIA', df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO AVANTE", 'AVANTE', df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO PDT", 'PDT', df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO PSOL", 'PSOL', df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO PROGRESSISTAS", 'PROGRESSISTAS',df_copia.sgPartido)
df_copia['sgPartido'] = np.where(df_copia['txNomeParlamentar'] == "LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL", 'SOCIAL', df_copia.sgPartido)

# %%
# Verificando quantos partidos não possuem registros de UF
sem_partido_sem_uf['txNomeParlamentar'].value_counts()
# Out:
# LIDERANÇA DO PT                                     515
# LIDERANÇA DO PTB                                    169
# LIDERANÇA DO PSDB                                   168
# LIDERANÇA DO PODEMOS                                140
# LIDERANÇA DO SOLIDARIEDADE                          137
# LIDERANÇA DO PSD                                    104
# LIDERANÇA DO NOVO                                    94
# LIDERANÇA DO DEMOCRATAS                              75
# LIDERANÇA DO CIDADANIA                               68
# LIDMIN                                               67
# LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL     51
# LIDERANÇA DO AVANTE                                  49
# LIDERANÇA DO PDT                                     36
# LIDERANÇA DO PSL                                     29
# LID.GOV-CD                                           15
# LIDERANÇA DO PSOL                                    14
# LIDERANÇA DO PROGRESSISTAS                           10
# Name: txNomeParlamentar, dtype: int64

# %%
# Realizando a contagem de frequência por estado dentro do DataFrame
df_unico.sgUF.value_counts()
# Out:
# SP    83873
# MG    65193
# RJ    50674
# RS    48467
# BA    43331
# PR    41816
# PE    28292
# SC    19900
# CE    19632
# MA    14412
# PA    14402
# PB    12727
# GO    11315
# RN    10183
# ES     9516
# TO     9378
# MT     9260
# MS     7970
# RO     7512
# PI     7284
# AC     6702
# AL     6629
# SE     6124
# AM     5723
# RR     5405
# AP     5216
# DF     2823
# Name: sgUF, dtype: int64

# %%
#Verificando o funcionamento da atribuição
df_copia[df_copia['txNomeParlamentar'].str.match('LIDERANÇA')].sample(5)
# Out:
#                                     txNomeParlamentar  cpf  ideCadastro  \
# 366                        LIDERANÇA DO SOLIDARIEDADE  NaN          NaN
# 584                                   LIDERANÇA DO PT  NaN          NaN
# 68   LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  NaN          NaN
# 583                                   LIDERANÇA DO PT  NaN          NaN
# 210                              LIDERANÇA DO PODEMOS  NaN          NaN
#
#      nuCarteiraParlamentar  nuLegislatura sgUF      sgPartido  codLegislatura  \
# 366                    NaN           2019  NaN  SOLIDARIEDADE              56
# 584                    NaN           2019  NaN             PT              56
# 68                     NaN           2019  NaN         SOCIAL              56
# 583                    NaN           2019  NaN             PT              56
# 210                    NaN           2019  NaN        PODEMOS              56
#
#      numSubCota                                   txtDescricao  ...  numAno  \
# 366          13     FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2020
# 584           9                     PASSAGEM AÉREA - REEMBOLSO  ...    2019
# 68            5           DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  ...    2020
# 583           9                     PASSAGEM AÉREA - REEMBOLSO  ...    2019
# 210           4  CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.  ...    2019
#
#     numParcela            txtPassageiro txtTrecho  numLote  numRessarcimento  \
# 366          0                      NaN       NaN  1687182               NaN
# 584          0  MAGDA BEATRIS DA SILVA;       NaN  1620686               NaN
# 68           0                      NaN       NaN  1714740               NaN
# 583          0  MAGDA BEATRIS DA SILVA;       NaN  1620686               NaN
# 210          0                      NaN       NaN  1617124               NaN
#
#     vlrRestituicao  nuDeputadoId  ideDocumento  \
# 366            NaN          2864       7038388
# 584            NaN          2439       6890572
# 68             NaN          2865       7089631
# 583            NaN          2439       6890447
# 210            NaN          3172       6881857
#
#                                           urlDocumento
# 366  http://camara.leg.br/cota-parlamentar/nota-fis...
# 584  https://www.camara.leg.br/cota-parlamentar/doc...
# 68   http://camara.leg.br/cota-parlamentar/nota-fis...
# 583  https://www.camara.leg.br/cota-parlamentar/doc...
# 210  http://camara.leg.br/cota-parlamentar/nota-fis...
#
# [5 rows x 31 columns]

# %%
#Criando uma cópia para trabalharmos nas questões e realizar as análises devidas
df_2 = df_copia.copy()

# %% [markdown]
# # MÓDULO 6 - TOCANTINS

# %%
#Mostrar as colunas para explorarmos o df
df_copia.columns
# Out:
# Index(['txNomeParlamentar', 'cpf', 'ideCadastro', 'nuCarteiraParlamentar',
#        'nuLegislatura', 'sgUF', 'sgPartido', 'codLegislatura', 'numSubCota',
#        'txtDescricao', 'numEspecificacaoSubCota', 'txtDescricaoEspecificacao',
#        'txtFornecedor', 'txtCNPJCPF', 'txtNumero', 'indTipoDocumento',
#        'datEmissao', 'vlrDocumento', 'vlrGlosa', 'vlrLiquido', 'numMes',
#        'numAno', 'numParcela', 'txtPassageiro', 'txtTrecho', 'numLote',
#        'numRessarcimento', 'vlrRestituicao', 'nuDeputadoId', 'ideDocumento',
#        'urlDocumento'],
#       dtype='object')

# %%
#Novo dataframe com o filtro só para deputados do estado de Tocantins
df_TO = df_copia[df_copia['sgUF'] == 'TO']

# %%
#Simples visualização dos primeiros registros
df_TO.head(2)
# Out:
#       txNomeParlamentar           cpf  ideCadastro  nuCarteiraParlamentar  \
# 22968     FREIRE JÚNIOR  7.402202e+10      74189.0                  615.0
# 22969     FREIRE JÚNIOR  7.402202e+10      74189.0                  615.0
#
#        nuLegislatura sgUF sgPartido  codLegislatura  numSubCota  \
# 22968           2015   TO       MDB              55           3
# 22969           2015   TO       MDB              55           3
#
#                         txtDescricao  ...  numAno numParcela txtPassageiro  \
# 22968  COMBUSTÍVEIS E LUBRIFICANTES.  ...    2019          0           NaN
# 22969  COMBUSTÍVEIS E LUBRIFICANTES.  ...    2019          0           NaN
#
#       txtTrecho  numLote  numRessarcimento vlrRestituicao  nuDeputadoId  \
# 22968       NaN  1552679               NaN            NaN           496
# 22969       NaN  1557161               NaN            NaN           496
#
#        ideDocumento                                       urlDocumento
# 22968       6733941  http://camara.leg.br/cota-parlamentar/nota-fis...
# 22969       6744495  http://camara.leg.br/cota-parlamentar/nota-fis...
#
# [2 rows x 31 columns]

# %%
#Instalação do package requests para capturarmos dados por meio da url
#!pip3 install requests

# %%
#Importação das libs que trabalharemos e configurar display para visualizar todas as colunas (jupyter)
import requests
import json as js
pd.set_option('display.max_rows', None)

# %%
#Rascunhos
"""
request = requests.get("https://minhareceita.org/CNPJ")
request = js.loads(request.content)
df_exemplo = pd.DataFrame([request])
df_exemplo"""
# Out:
# '\nrequest = requests.get("https://minhareceita.org/CNPJ")\nrequest = js.loads(request.content)\ndf_exemplo = pd.DataFrame([request])\ndf_exemplo'

# %%
#Seleção dos cnpj/cpf com total de soma e ordenado para somente os 10 primeiros. Transformandos a series em df e aplicamos...
#nome da coluna de retorno do groupby de Valor e resetamos o index
df_gasto = pd.DataFrame({'Valor': df_copia.groupby(['txtCNPJCPF'])['vlrDocumento'].sum().sort_values(ascending = False).head(10)}).reset_index()
df_gasto
# Out:
#            txtCNPJCPF         Valor
# 0  020.128.620/0016-0  3.517576e+07
# 1  075.756.510/0015-9  3.050471e+07
# 2  092.962.950/0016-0  9.269181e+06
# 3  073.193.230/0019-1  6.333604e+06
# 4  025.581.570/0016-2  5.459504e+06
# 5  000.000.000/0000-7  3.579859e+06
# 6  267.352.270/0017-9  2.900098e+06
# 7  000.000.000/0000-1  2.618129e+06
# 8  026.102.350/0012-0  2.263000e+06
# 9  054.434.490/0014-8  1.862697e+06

# %%
#Atribuímos o retorno do get no formado json à nova coluna dados_CNPJ em nosso dataframe do groupby
df_gasto['dados_CNPJ'] = df_gasto['txtCNPJCPF'].map(lambda x: requests.get(f"https://minhareceita.org/{x}"))

# %%
#Atribuímos a formatação do json para modelo de dicionário
df_gasto['dados_CNPJ'] = df_gasto['dados_CNPJ'].map(lambda x: js.loads(x.content))

# %%
#Simples visualização formatando o dict em list e convertendo-o em dataframe
pd.DataFrame(list(df_gasto['dados_CNPJ']))
# Out:
#     uf       cep                                                qsa  \
# 0   SP  04634042  [{'pais': None, 'nome_socio': 'JEROME PAUL JAC...
# 1   RJ  20021340  [{'pais': None, 'nome_socio': 'PAULO SERGIO KA...
# 2   SP  06460040  [{'pais': None, 'nome_socio': 'ANTONIO FLAVIO ...
# 3   DF  70316000  [{'pais': None, 'nome_socio': 'MARCIA DIAS YOS...
# 4   SP  04571936  [{'pais': None, 'nome_socio': 'BRENO RODRIGO P...
# 5  NaN       NaN                                                NaN
# 6   DF  70390055  [{'pais': None, 'nome_socio': 'JULIANA LOMAZZI...
# 7  NaN       NaN                                                NaN
# 8   DF  70340906  [{'pais': None, 'nome_socio': 'MARCOS ALESSAND...
# 9   DF  70070934  [{'pais': None, 'nome_socio': 'CLEONIDES DE SO...
#
#              cnpj  pais                     porte                    bairro  \
# 0  02012862000160   NaN                    DEMAIS  JARDIM BRASIL (ZONA SUL)
# 1  07575651000159   NaN                    DEMAIS                    CENTRO
# 2  09296295000160   NaN                    DEMAIS                   TAMBORE
# 3  07319323000191   NaN  EMPRESA DE PEQUENO PORTE                   ASA SUL
# 4  02558157000162   NaN                    DEMAIS            CIDADE MONCOES
# 5             NaN   NaN                       NaN                       NaN
# 6  26735227000179   NaN             MICRO EMPRESA                   ASA SUL
# 7             NaN   NaN                       NaN                       NaN
# 8  02610235000120   NaN             MICRO EMPRESA                   ASA SUL
# 9  05443449000148   NaN                    DEMAIS                   ASA SUL
#
#   numero     ddd_fax       municipio  ... codigo_natureza_juridica  \
# 0    673  1155826118       SAO PAULO  ...                   2054.0
# 1    S/N  1128412702  RIO DE JANEIRO  ...                   2054.0
# 2    939  1141349800         BARUERI  ...                   2054.0
# 3     SN  6133224595        BRASILIA  ...                   2062.0
# 4   1376  1138895374       SAO PAULO  ...                   2046.0
# 5    NaN         NaN             NaN  ...                      NaN
# 6     25                    BRASILIA  ...                   2305.0
# 7    NaN         NaN             NaN  ...                      NaN
# 8     38                    BRASILIA  ...                   2062.0
# 9    S/N  0613236025        BRASILIA  ...                   3999.0
#
#    data_exclusao_do_simples  motivo_situacao_cadastral  \
# 0                      None                        0.0
# 1                      None                        0.0
# 2                      None                        0.0
# 3                2010-12-31                        0.0
# 4                      None                        0.0
# 5                       NaN                        NaN
# 6                      None                        0.0
# 7                       NaN                        NaN
# 8                      None                        0.0
# 9                      None                        0.0
#
#   ente_federativo_responsavel  identificador_matriz_filial  \
# 0                                                      1.0
# 1                                                      1.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      1.0
# 5                         NaN                          NaN
# 6                                                      1.0
# 7                         NaN                          NaN
# 8                                                      1.0
# 9                                                      1.0
#
#   qualificacao_do_responsavel descricao_situacao_cadastral  \
# 0                        16.0                        ATIVA
# 1                        16.0                        ATIVA
# 2                        16.0                        ATIVA
# 3                        49.0                        ATIVA
# 4                        16.0                        ATIVA
# 5                         NaN                          NaN
# 6                        65.0                        ATIVA
# 7                         NaN                          NaN
# 8                        49.0                        ATIVA
# 9                        16.0                        ATIVA
#
#    descricao_tipo_de_logradouro descricao_motivo_situacao_cadastral  \
# 0                           RUA                          SEM MOTIVO
# 1                         PRACA                          SEM MOTIVO
# 2                       AVENIDA                          SEM MOTIVO
# 3                         SETOR                          SEM MOTIVO
# 4                       AVENIDA                          SEM MOTIVO
# 5                           NaN                                 NaN
# 6                        QUADRA                          SEM MOTIVO
# 7                           NaN                                 NaN
# 8                         SETOR                          SEM MOTIVO
# 9                           RUA                          SEM MOTIVO
#
#                              message
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5  CNPJ 00.000.000/0000-07 inválido.
# 6                                NaN
# 7  CNPJ 00.000.000/0000-01 inválido.
# 8                                NaN
# 9                                NaN
#
# [10 rows x 46 columns]

# %% [markdown]
# # Laio

# %% [markdown]
# # Sartorio

# %% [markdown]
# # Gui

# %% [markdown]
# # Jonathas

# %%
dfto = df_TO.copy()
dfto.reset_index(drop=True, inplace=True)

# %%
dfto.cpf = dfto.cpf.astype('int64')

# %%
semCnpj = dfto[dfto['txtCNPJCPF'].isna()]
comCnpj = dfto[dfto['txtCNPJCPF'].notna()]
selecao = comCnpj.txtCNPJCPF.str.contains('000.000.000/')
cnpjInvalidos = comCnpj[comCnpj.txtCNPJCPF.str.contains('000.000.000/')]
comCnpj = comCnpj[~selecao]

# %%
dic = {'Com CNPJ': [comCnpj], 'Sem CNPJ': [semCnpj], 'CNPJ Inválidos': [cnpjInvalidos]}
plt.bar(['Com CNPJ','Sem CNPJ', 'CNPJ Inválidos'], [comCnpj.shape[0], semCnpj.shape[0], cnpjInvalidos.shape[0]])
# Out:
# <BarContainer object of 3 artists>

# %%
dfto['txNomeParlamentar'].unique()
# Out:
# array(['FREIRE JÚNIOR', 'JOSI NUNES', 'Vicentinho Júnior',
#        'LÁZARO BOTELHO', 'Tiago Dimas', 'CÉSAR HALUM',
#        'Professora Dorinha Seabra Rezende', 'Carlos Henrique Gaguim',
#        'Dulce Miranda', 'Osires Damaso', 'Eli Borges', 'Célio Moura'],
#       dtype=object)

# %%
round(dfto['vlrDocumento'].describe(), 2)
# Out:
# count      9378.00
# mean        920.31
# std        3265.15
# min       -2592.63
# 25%         100.00
# 50%         224.00
# 75%         582.62
# max      109500.00
# Name: vlrDocumento, dtype: float64

# %%
for descricao in df_TO.txtDescricao.unique():
    temp = df_TO[df_TO['txtDescricao'] == descricao]
    plt.boxplot(temp['vlrDocumento'])
    plt.title(descricao)
    plt.show()

# %%
dfCelio = dfto[dfto['txNomeParlamentar'] == 'Célio Moura']

# %%
round(dfCelio[['vlrDocumento', 'vlrGlosa', 'vlrLiquido', 'vlrRestituicao']].describe(), 2)
# Out:
#        vlrDocumento  vlrGlosa  vlrLiquido  vlrRestituicao
# count       1855.00   1855.00     1855.00             0.0
# mean         504.08      1.27      438.87             NaN
# std         1624.65     14.45     1641.81             NaN
# min        -2592.63      0.00    -2592.63             NaN
# 25%           39.05      0.00       33.59             NaN
# 50%          139.02      0.00      127.65             NaN
# 75%          337.98      0.00      262.56             NaN
# max        44560.00    550.40    44560.00             NaN

# %%
gbCelio = dfCelio.groupby('txtDescricao')['vlrDocumento'].describe()

# %%
round(gbCelio.describe(), 2)
# Out:
#         count     mean      std      min      25%      50%      75%       max
# count   13.00    13.00    13.00    13.00    13.00    13.00    13.00     13.00
# mean   142.69  1060.64   897.61   -80.89   705.06   885.70  1254.02   5762.61
# std    128.61  1727.95  1507.90   779.18  1615.92  1609.16  1931.30  11871.02
# min     12.00    12.93     7.15 -2592.63     8.80    10.46    14.38     45.51
# 25%     55.00   121.44   109.34     4.90    39.39   119.99   138.84    863.75
# 50%     92.00   268.28   395.45    24.30   127.44   184.96   262.25   2587.50
# 75%    223.00  1049.98   910.54    60.20   641.14  1001.07  1500.56   3938.74
# max    472.00  6346.67  5692.65   600.00  6000.00  6000.00  7000.00  44560.00

# %%
selecao = dfCelio['txtDescricao'].isin(['FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR'])

# %%
alimentacao = dfCelio[selecao]
alimentacao.shape[0]
# Out:
# 237

# %%
plt.hist(alimentacao['vlrDocumento'])
# Out:
# (array([ 52., 125.,  38.,  12.,   7.,   2.,   0.,   0.,   0.,   1.]),
#  array([  8.5 ,  26.15,  43.8 ,  61.45,  79.1 ,  96.75, 114.4 , 132.05,
#         149.7 , 167.35, 185.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(alimentacao['vlrDocumento'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xc123797d30>,
#   <matplotlib.lines.Line2D at 0xc1237a50d0>],
#  'caps': [<matplotlib.lines.Line2D at 0xc1237a5430>,
#   <matplotlib.lines.Line2D at 0xc1237a5790>],
#  'boxes': [<matplotlib.lines.Line2D at 0xc1237979d0>],
#  'medians': [<matplotlib.lines.Line2D at 0xc1237a5af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0xc1237a5e50>],
#  'means': []}

# %%
alimentacao[alimentacao['vlrDocumento'] > 100].T
# Out:
#                                                                         4036  \
# txNomeParlamentar                                                Célio Moura
# cpf                                                              12364983134
# ideCadastro                                                         204370.0
# nuCarteiraParlamentar                                                   62.0
# nuLegislatura                                                           2019
# sgUF                                                                      TO
# sgPartido                                                                 PT
# codLegislatura                                                            56
# numSubCota                                                                13
# txtDescricao                      FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# numEspecificacaoSubCota                                                    0
# txtDescricaoEspecificacao                                                NaN
# txtFornecedor               EMBAIXADA GASTRONOMICA BAR RESTAURANTE E EVENTOS
# txtCNPJCPF                                                119.990.920/0018-1
# txtNumero                                                              85283
# indTipoDocumento                                                           4
# datEmissao                                               2019-08-13 00:00:00
# vlrDocumento                                                          101.75
# vlrGlosa                                                                9.25
# vlrLiquido                                                              92.5
# numMes                                                                     8
# numAno                                                                  2019
# numParcela                                                                 0
# txtPassageiro                                                            NaN
# txtTrecho                                                                NaN
# numLote                                                              1622078
# numRessarcimento                                                         NaN
# vlrRestituicao                                                           NaN
# nuDeputadoId                                                            3203
# ideDocumento                                                         6892422
# urlDocumento               http://camara.leg.br/cota-parlamentar/nota-fis...
#
#                                                                         7304
# txNomeParlamentar                                                Célio Moura
# cpf                                                              12364983134
# ideCadastro                                                         204370.0
# nuCarteiraParlamentar                                                   62.0
# nuLegislatura                                                           2019
# sgUF                                                                      TO
# sgPartido                                                                 PT
# codLegislatura                                                            56
# numSubCota                                                                13
# txtDescricao                      FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# numEspecificacaoSubCota                                                    0
# txtDescricaoEspecificacao                                                NaN
# txtFornecedor                                  Santo Canto Restaurantes Ltda
# txtCNPJCPF                                                354.648.510/0017-0
# txtNumero                                                                130
# indTipoDocumento                                                           0
# datEmissao                                               2020-10-12 00:00:00
# vlrDocumento                                                           185.0
# vlrGlosa                                                                 0.0
# vlrLiquido                                                             185.0
# numMes                                                                    10
# numAno                                                                  2020
# numParcela                                                                 0
# txtPassageiro                                                            NaN
# txtTrecho                                                                NaN
# numLote                                                              1722431
# numRessarcimento                                                         NaN
# vlrRestituicao                                                           NaN
# nuDeputadoId                                                            3203
# ideDocumento                                                         7105504
# urlDocumento               https://www.camara.leg.br/cota-parlamentar/doc...

# %%
alimentacao['urlDocumento'].loc[4036]
# Out:
# 'http://camara.leg.br/cota-parlamentar/nota-fiscal-eletronica?ideDocumentoFiscal=6892422'

# %%
alimentacao['urlDocumento'].loc[7304]
# Out:
# 'https://www.camara.leg.br/cota-parlamentar/documentos/publ/3203/2020/7105504.pdf'

# %%
alimentacao['dados_CNPJ'] = alimentacao['txtCNPJCPF'].map(lambda x: requests.get(f"https://minhareceita.org/{x}"))
# Out:
# <ipython-input-113-31128b074969>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alimentacao['dados_CNPJ'] = alimentacao['txtCNPJCPF'].map(lambda x: requests.get(f"https://minhareceita.org/{x}"))

# %%
alimentacao['dados_CNPJ'].head(2)
# Out:
# 4023    {'uf': 'DF', 'cep': '70832515', 'qsa': [{'pais...
# 4024    {'uf': 'TO', 'cep': '77660000', 'qsa': [{'pais...
# Name: dados_CNPJ, dtype: object

# %%
alimentacao['dados_CNPJ'] = alimentacao['dados_CNPJ'].map(lambda x: js.loads(x.content))
# Out:
# <ipython-input-115-722af9320587>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alimentacao['dados_CNPJ'] = alimentacao['dados_CNPJ'].map(lambda x: js.loads(x.content))

# %%
df_2Celio = pd.DataFrame(list(alimentacao['dados_CNPJ']))

# %%
df_2Celio[['razao_social', 'data_situacao_cadastral', 'data_inicio_atividade', 'descricao_motivo_situacao_cadastral', 'descricao_situacao_cadastral']]
# Out:
#                                           razao_social  \
# 0         202 OPEN SHOPPING COMERCIO DE ALIMENTOS LTDA
# 1               RESTAURANTE RAJA GAUCHA MIRANORTE LTDA
# 2                     BAR E RESTAURANTE TIA ZELIA LTDA
# 3                     BAR E RESTAURANTE TIA ZELIA LTDA
# 4               BARBOSA COMERCIO DE ALIMENTOS - EIRELI
# 5                          BRASEIRO - RESTAURANTE LTDA
# 6                        CALIFORNIA CAFE E BISTRO LTDA
# 7                  CARNE DE SOL 111 RESTAURANTE EIRELI
# 8        CHURRASCARIA & CHOPERIA RECANTO GAUCHO EIRELI
# 9                                CARDOSO E COELHO LTDA
# 10                                      CPQ BRASIL S/A
# 11                                  R R ALIMENTOS LTDA
# 12                     EGCL COMERCIO DE ALIMENTOS LTDA
# 13   EMBAIXADA GASTRONOMICA BAR, RESTAURANTE E EVEN...
# 14   EMBAIXADA GASTRONOMICA BAR, RESTAURANTE E EVEN...
# 15                   JERIVA COMERCIO DE ALIMENTOS LTDA
# 16                   JERIVA COMERCIO DE ALIMENTOS LTDA
# 17                   JERIVA COMERCIO DE ALIMENTOS LTDA
# 18                   DISTRIBUIDORA IMPERIO DO SUL LTDA
# 19                   DISTRIBUIDORA IMPERIO DO SUL LTDA
# 20                   DISTRIBUIDORA IMPERIO DO SUL LTDA
# 21                        LE JADY'S RESTAURANTE EIRELI
# 22                            MARCELA FEITOSA MENDANHA
# 23                              MAURO CHURRASCO EIRELI
# 24                             MJS RESTAURANTES EIRELI
# 25           PRATES FOODS COMERCIO DE ALIMENTOS EIRELI
# 26                       RESTAURANTE DOM VERGILIO LTDA
# 27                       RESTAURANTE DOM VERGILIO LTDA
# 28                              R. F. SIMON & CIA LTDA
# 29                              R. F. SIMON & CIA LTDA
# 30                              R. F. SIMON & CIA LTDA
# 31                     RESTAURANTE VARANDA DO SUL LTDA
# 32                     RESTAURANTE VARANDA DO SUL LTDA
# 33                     RESTAURANTE VARANDA DO SUL LTDA
# 34                     RESTAURANTE VARANDA DO SUL LTDA
# 35                     RESTAURANTE VARANDA DO SUL LTDA
# 36                                          B H L LTDA
# 37                            ROMARIO CARVALHO PEREIRA
# 38                S A LEAL COMERCIAL DE ALIMENTOS LTDA
# 39                                SALADA SAO JOAO LTDA
# 40    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 41    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 42    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 43    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 44    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 45    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 46    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 47    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 48    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 49    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 50    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 51    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 52    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 53    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 54    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 55    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 56    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 57    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 58    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 59    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 60    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 61    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 62    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 63    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 64    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 65    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 66    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 67    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 68    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 69    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 70    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 71    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 72    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 73    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 74    SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 75                            SILT SELF SERVICE EIRELI
# 76                            SILT SELF SERVICE EIRELI
# 77                            SILT SELF SERVICE EIRELI
# 78                            SILT SELF SERVICE EIRELI
# 79                            SILT SELF SERVICE EIRELI
# 80                            SILT SELF SERVICE EIRELI
# 81                            SILT SELF SERVICE EIRELI
# 82                            SILT SELF SERVICE EIRELI
# 83                            SILT SELF SERVICE EIRELI
# 84                            SILT SELF SERVICE EIRELI
# 85                            SILT SELF SERVICE EIRELI
# 86                            SILT SELF SERVICE EIRELI
# 87                            SILT SELF SERVICE EIRELI
# 88                            SILT SELF SERVICE EIRELI
# 89                            SILT SELF SERVICE EIRELI
# 90                            SILT SELF SERVICE EIRELI
# 91                            SILT SELF SERVICE EIRELI
# 92                            SILT SELF SERVICE EIRELI
# 93                            SILT SELF SERVICE EIRELI
# 94                            SILT SELF SERVICE EIRELI
# 95                            SILT SELF SERVICE EIRELI
# 96                            SILT SELF SERVICE EIRELI
# 97                            SILT SELF SERVICE EIRELI
# 98                            SILT SELF SERVICE EIRELI
# 99                            SILT SELF SERVICE EIRELI
# 100                           SILT SELF SERVICE EIRELI
# 101                           SILT SELF SERVICE EIRELI
# 102                           SILT SELF SERVICE EIRELI
# 103                           SILT SELF SERVICE EIRELI
# 104                           SILT SELF SERVICE EIRELI
# 105                           SILT SELF SERVICE EIRELI
# 106                           SILT SELF SERVICE EIRELI
# 107                           SILT SELF SERVICE EIRELI
# 108                           SILT SELF SERVICE EIRELI
# 109                           SILT SELF SERVICE EIRELI
# 110                           SILT SELF SERVICE EIRELI
# 111                           SILT SELF SERVICE EIRELI
# 112                           SILT SELF SERVICE EIRELI
# 113                       BAR E WISKERIA BRASILIA LTDA
# 114           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 115           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 116           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 117           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 118           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 119           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 120           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 121           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 122           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 123           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 124                         CASA DOCE CONFEITARIA LTDA
# 125                                  CG ALIMENTOS LTDA
# 126                                  CG ALIMENTOS LTDA
# 127                                  CG ALIMENTOS LTDA
# 128                                  CG ALIMENTOS LTDA
# 129                                  CG ALIMENTOS LTDA
# 130                                  CG ALIMENTOS LTDA
# 131                                  CG ALIMENTOS LTDA
# 132                                  CG ALIMENTOS LTDA
# 133                                  CG ALIMENTOS LTDA
# 134                                  CG ALIMENTOS LTDA
# 135                                  CG ALIMENTOS LTDA
# 136                                  CG ALIMENTOS LTDA
# 137                                  CG ALIMENTOS LTDA
# 138                                  CG ALIMENTOS LTDA
# 139                                  CG ALIMENTOS LTDA
# 140                                  CG ALIMENTOS LTDA
# 141                                  CG ALIMENTOS LTDA
# 142                                  CG ALIMENTOS LTDA
# 143                                  CG ALIMENTOS LTDA
# 144                                  CG ALIMENTOS LTDA
# 145                                  CG ALIMENTOS LTDA
# 146                        DIOGENES C. FERREIRA EIRELI
# 147          ELZA GONCALVES DE OLIVEIRA PEDROSA EIRELI
# 148                 FLOR DE PEQUI GRILL E PIZZA EIRELI
# 149                      GZ COMERCIO DE ALIMENTOS LTDA
# 150                   ILNA CARNEIRO VIDAL ALVES EIRELI
# 151                                  JEANE ROSA FREIRE
# 152                  JERIVA COMERCIO DE ALIMENTOS LTDA
# 153                  JERIVA COMERCIO DE ALIMENTOS LTDA
# 154                  DISTRIBUIDORA IMPERIO DO SUL LTDA
# 155                  DISTRIBUIDORA IMPERIO DO SUL LTDA
# 156                  DISTRIBUIDORA IMPERIO DO SUL LTDA
# 157              NAPOLITANA COMERCIO DE ALIMENTOS LTDA
# 158              NAPOLITANA COMERCIO DE ALIMENTOS LTDA
# 159                               NDT ALIMENTOS EIRELI
# 160                 NEIDISON PEIXOTO DOS SANTOS EIRELI
# 161                         R S SILVA ALIMENTOS EIRELI
# 162                         R S SILVA ALIMENTOS EIRELI
# 163                           R. G. DE OLIVEIRA EIRELI
# 164             THIAGO FREU - RAJA GAUCHA CHURRASCARIA
# 165                      RESTAURANTE DOM VERGILIO LTDA
# 166              RESTAURANTE E LANCHONETE CAMPELO LTDA
# 167                           RESTAURANTE GABMELL LTDA
# 168                           RESTAURANTE GABMELL LTDA
# 169                        RESTAURANTE PAG O PESO LTDA
# 170                          E M DIAS DE FREITAS  LTDA
# 171            BENEVALDO FERREIRA DA SILVA 59721073172
# 172                    RESTAURANTE VARANDA DO SUL LTDA
# 173                    RESTAURANTE VARANDA DO SUL LTDA
# 174                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 175                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 176                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 177                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 178                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 179                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 180                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 181                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 182                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 183                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 184                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 185                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 186                           ROMARIO CARVALHO PEREIRA
# 187                                 ROSSI & ROSSI LTDA
# 188                      SANTO CANTO RESTAURANTES LTDA
# 189   SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 190   SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 191   SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 192   SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 193   SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 194   SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 195   SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 196   SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
# 197                           SILT SELF SERVICE EIRELI
# 198                           SILT SELF SERVICE EIRELI
# 199                           SILT SELF SERVICE EIRELI
# 200                           SILT SELF SERVICE EIRELI
# 201                           SILT SELF SERVICE EIRELI
# 202                           SILT SELF SERVICE EIRELI
# 203                   COMBO COMERCIO DE ALIMENTOS LTDA
# 204                           R. G. DE OLIVEIRA EIRELI
# 205                      TORO GRILL RESTAURANTE EIRELI
# 206           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 207           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 208           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 209           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 210           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 211           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 212           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 213           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 214           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 215           CARNE DE SOL EXPRESSO RESTAURANTE EIRELI
# 216                          DISTRIBUIDORA CRIXAS LTDA
# 217                      DU CAFFIER CAFE E BUFFET LTDA
# 218                      DU CAFFIER CAFE E BUFFET LTDA
# 219                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 220                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 221                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 222                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 223                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 224                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 225                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 226                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 227                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 228                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 229                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 230                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 231                  RMAM COMERCIO DE ALIMENTOS EIRELI
# 232                  S.P. V COMERCIO DE ALIMENTOS LTDA
# 233                  S.P. V COMERCIO DE ALIMENTOS LTDA
# 234                 SERRANA COMERCIO DE ALIMENTOS LTDA
# 235                 SERRANA COMERCIO DE ALIMENTOS LTDA
# 236   SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC
#
#     data_situacao_cadastral data_inicio_atividade  \
# 0                2000-11-20            2000-11-20
# 1                2009-10-15            2009-10-15
# 2                2010-09-06            2010-09-06
# 3                2010-09-06            2010-09-06
# 4                2015-06-29            2015-06-29
# 5                2010-10-04            2010-10-04
# 6                2013-05-07            2013-05-07
# 7                2005-11-03            1980-07-07
# 8                2019-04-12            2019-04-12
# 9                2014-01-09            2014-01-09
# 10               2017-03-17            2017-03-17
# 11               2017-01-18            2017-01-18
# 12               2011-10-28            2011-10-28
# 13               2010-05-24            2010-05-24
# 14               2010-05-24            2010-05-24
# 15               2005-11-03            1977-03-28
# 16               2005-11-03            1977-03-28
# 17               2012-06-15            2012-06-15
# 18               2018-03-15            2018-03-15
# 19               2018-03-15            2018-03-15
# 20               2018-03-15            2018-03-15
# 21               2014-12-03            2014-12-03
# 22               2012-01-30            2012-01-30
# 23               2016-03-23            2016-03-23
# 24               2020-09-04            2016-03-04
# 25               2018-08-28            2018-08-28
# 26               2005-05-07            2003-11-12
# 27               2005-05-07            2003-11-12
# 28               2007-08-16            2007-08-16
# 29               2007-08-16            2007-08-16
# 30               2007-08-16            2007-08-16
# 31               2005-11-03            2001-06-11
# 32               2005-11-03            2001-06-11
# 33               2005-11-03            2001-06-11
# 34               2005-11-03            2001-06-11
# 35               2005-11-03            2001-06-11
# 36               2011-06-08            2011-06-08
# 37               2014-01-29            2014-01-29
# 38               2017-05-05            2017-05-05
# 39               2005-11-03            1966-08-26
# 40               2008-03-17            2008-03-17
# 41               2008-03-17            2008-03-17
# 42               2008-03-17            2008-03-17
# 43               2008-03-17            2008-03-17
# 44               2008-03-17            2008-03-17
# 45               2008-09-05            2008-09-05
# 46               2009-04-13            2009-04-13
# 47               2009-04-13            2009-04-13
# 48               2009-04-13            2009-04-13
# 49               2009-04-13            2009-04-13
# 50               2009-04-13            2009-04-13
# 51               2009-04-13            2009-04-13
# 52               2009-04-13            2009-04-13
# 53               2009-04-13            2009-04-13
# 54               2009-04-13            2009-04-13
# 55               2009-04-13            2009-04-13
# 56               2009-04-13            2009-04-13
# 57               2009-04-13            2009-04-13
# 58               2009-04-13            2009-04-13
# 59               2009-04-13            2009-04-13
# 60               2009-04-13            2009-04-13
# 61               2009-04-13            2009-04-13
# 62               2009-04-13            2009-04-13
# 63               2009-04-13            2009-04-13
# 64               2009-04-13            2009-04-13
# 65               2009-04-13            2009-04-13
# 66               2009-04-13            2009-04-13
# 67               2009-04-13            2009-04-13
# 68               2009-04-13            2009-04-13
# 69               2009-04-13            2009-04-13
# 70               2009-04-13            2009-04-13
# 71               2009-04-13            2009-04-13
# 72               2009-04-13            2009-04-13
# 73               2009-04-13            2009-04-13
# 74               2009-04-13            2009-04-13
# 75               2005-03-16            2005-03-16
# 76               2005-03-16            2005-03-16
# 77               2005-03-16            2005-03-16
# 78               2005-03-16            2005-03-16
# 79               2005-03-16            2005-03-16
# 80               2005-03-16            2005-03-16
# 81               2005-03-16            2005-03-16
# 82               2005-03-16            2005-03-16
# 83               2005-03-16            2005-03-16
# 84               2005-03-16            2005-03-16
# 85               2005-03-16            2005-03-16
# 86               2005-03-16            2005-03-16
# 87               2005-03-16            2005-03-16
# 88               2005-03-16            2005-03-16
# 89               2005-03-16            2005-03-16
# 90               2005-03-16            2005-03-16
# 91               2005-03-16            2005-03-16
# 92               2005-03-16            2005-03-16
# 93               2005-03-16            2005-03-16
# 94               2005-03-16            2005-03-16
# 95               2005-03-16            2005-03-16
# 96               2005-03-16            2005-03-16
# 97               2005-03-16            2005-03-16
# 98               2005-03-16            2005-03-16
# 99               2005-03-16            2005-03-16
# 100              2005-03-16            2005-03-16
# 101              2005-03-16            2005-03-16
# 102              2005-03-16            2005-03-16
# 103              2005-03-16            2005-03-16
# 104              2005-03-16            2005-03-16
# 105              2005-03-16            2005-03-16
# 106              2005-03-16            2005-03-16
# 107              2005-03-16            2005-03-16
# 108              2005-03-16            2005-03-16
# 109              2005-03-16            2005-03-16
# 110              2005-03-16            2005-03-16
# 111              2005-03-16            2005-03-16
# 112              2005-03-16            2005-03-16
# 113              2002-03-05            2002-03-05
# 114              2005-11-03            1983-03-09
# 115              2005-11-03            1983-03-09
# 116              2005-11-03            1983-03-09
# 117              2005-11-03            1983-03-09
# 118              2005-11-03            1983-03-09
# 119              2005-11-03            1983-03-09
# 120              2005-11-03            1983-03-09
# 121              2005-11-03            1983-03-09
# 122              2005-11-03            1983-03-09
# 123              2005-11-03            1983-03-09
# 124              2005-11-03            2003-10-22
# 125              2002-06-08            1991-07-10
# 126              2002-06-08            1991-07-10
# 127              2002-06-08            1991-07-10
# 128              2002-06-08            1991-07-10
# 129              2002-06-08            1991-07-10
# 130              2002-06-08            1991-07-10
# 131              2002-06-08            1991-07-10
# 132              2002-06-08            1991-07-10
# 133              2002-06-08            1991-07-10
# 134              2002-06-08            1991-07-10
# 135              2002-06-08            1991-07-10
# 136              2002-06-08            1991-07-10
# 137              2002-06-08            1991-07-10
# 138              2002-06-08            1991-07-10
# 139              2002-06-08            1991-07-10
# 140              2002-06-08            1991-07-10
# 141              2002-06-08            1991-07-10
# 142              2002-06-08            1991-07-10
# 143              2002-06-08            1991-07-10
# 144              2002-06-08            1991-07-10
# 145              2002-06-08            1991-07-10
# 146              2018-04-03            2018-04-03
# 147              2022-01-04            2016-02-10
# 148              2015-10-21            2015-10-21
# 149              2017-02-17            2017-02-17
# 150              2011-04-28            2011-04-28
# 151              2016-10-27            2016-10-27
# 152              2005-11-03            1977-03-28
# 153              2005-11-03            1977-03-28
# 154              2018-03-15            2018-03-15
# 155              2018-03-15            2018-03-15
# 156              2018-03-15            2018-03-15
# 157              2010-04-22            2010-04-22
# 158              2010-04-22            2010-04-22
# 159              2019-09-09            1996-11-22
# 160              2005-11-03            2001-01-26
# 161              2017-02-24            2017-02-24
# 162              2017-02-24            2017-02-24
# 163              2018-12-17            2018-12-17
# 164              2012-08-16            2012-08-16
# 165              2005-05-07            2003-11-12
# 166              2018-08-23            2018-08-23
# 167              2012-08-15            2012-08-15
# 168              2012-08-15            2012-08-15
# 169              2004-03-12            1991-04-03
# 170              2005-11-03            1993-02-10
# 171              2021-07-06            2018-08-15
# 172              2005-11-03            2001-06-11
# 173              2005-11-03            2001-06-11
# 174              2018-05-15            2018-05-15
# 175              2018-05-15            2018-05-15
# 176              2018-05-15            2018-05-15
# 177              2018-05-15            2018-05-15
# 178              2018-05-15            2018-05-15
# 179              2018-05-15            2018-05-15
# 180              2018-05-15            2018-05-15
# 181              2018-05-15            2018-05-15
# 182              2018-05-15            2018-05-15
# 183              2018-05-15            2018-05-15
# 184              2018-05-15            2018-05-15
# 185              2018-05-15            2018-05-15
# 186              2014-01-29            2014-01-29
# 187              2000-12-23            1989-10-16
# 188              2022-01-04            2019-11-09
# 189              2008-03-17            2008-03-17
# 190              2008-03-17            2008-03-17
# 191              2008-03-17            2008-03-17
# 192              2009-04-13            2009-04-13
# 193              2009-04-13            2009-04-13
# 194              2009-04-13            2009-04-13
# 195              2009-04-13            2009-04-13
# 196              2009-04-13            2009-04-13
# 197              2005-03-16            2005-03-16
# 198              2005-03-16            2005-03-16
# 199              2005-03-16            2005-03-16
# 200              2005-03-16            2005-03-16
# 201              2005-03-16            2005-03-16
# 202              2005-03-16            2005-03-16
# 203              2020-06-02            2020-06-02
# 204              2018-12-17            2018-12-17
# 205              2019-05-29            2019-05-29
# 206              2005-11-03            1983-03-09
# 207              2005-11-03            1983-03-09
# 208              2005-11-03            1983-03-09
# 209              2005-11-03            1983-03-09
# 210              2005-11-03            1983-03-09
# 211              2005-11-03            1983-03-09
# 212              2005-11-03            1983-03-09
# 213              2005-11-03            1983-03-09
# 214              2005-11-03            1983-03-09
# 215              2005-11-03            1983-03-09
# 216              2020-03-11            2020-03-11
# 217              2006-07-21            2006-07-21
# 218              2006-07-21            2006-07-21
# 219              2018-05-15            2018-05-15
# 220              2018-05-15            2018-05-15
# 221              2018-05-15            2018-05-15
# 222              2018-05-15            2018-05-15
# 223              2018-05-15            2018-05-15
# 224              2018-05-15            2018-05-15
# 225              2018-05-15            2018-05-15
# 226              2018-05-15            2018-05-15
# 227              2018-05-15            2018-05-15
# 228              2018-05-15            2018-05-15
# 229              2018-05-15            2018-05-15
# 230              2018-05-15            2018-05-15
# 231              2018-05-15            2018-05-15
# 232              2016-06-14            2016-06-14
# 233              2016-06-14            2016-06-14
# 234              2008-04-18            2008-04-18
# 235              2008-04-18            2008-04-18
# 236              2008-03-17            2008-03-17
#
#                  descricao_motivo_situacao_cadastral  \
# 0                                         SEM MOTIVO
# 1                                         SEM MOTIVO
# 2                                         SEM MOTIVO
# 3                                         SEM MOTIVO
# 4                                         SEM MOTIVO
# 5                                         SEM MOTIVO
# 6                                         SEM MOTIVO
# 7                                         SEM MOTIVO
# 8                                         SEM MOTIVO
# 9                                         SEM MOTIVO
# 10                                        SEM MOTIVO
# 11                                        SEM MOTIVO
# 12                                        SEM MOTIVO
# 13                                        SEM MOTIVO
# 14                                        SEM MOTIVO
# 15                                        SEM MOTIVO
# 16                                        SEM MOTIVO
# 17                                        SEM MOTIVO
# 18                                        SEM MOTIVO
# 19                                        SEM MOTIVO
# 20                                        SEM MOTIVO
# 21                                        SEM MOTIVO
# 22                                        SEM MOTIVO
# 23                                        SEM MOTIVO
# 24   EXTINCAO POR ENCERRAMENTO LIQUIDACAO VOLUNTARIA
# 25                                        SEM MOTIVO
# 26                                        SEM MOTIVO
# 27                                        SEM MOTIVO
# 28                                        SEM MOTIVO
# 29                                        SEM MOTIVO
# 30                                        SEM MOTIVO
# 31                                        SEM MOTIVO
# 32                                        SEM MOTIVO
# 33                                        SEM MOTIVO
# 34                                        SEM MOTIVO
# 35                                        SEM MOTIVO
# 36                                        SEM MOTIVO
# 37                                        SEM MOTIVO
# 38                                        SEM MOTIVO
# 39                                        SEM MOTIVO
# 40                                        SEM MOTIVO
# 41                                        SEM MOTIVO
# 42                                        SEM MOTIVO
# 43                                        SEM MOTIVO
# 44                                        SEM MOTIVO
# 45                                        SEM MOTIVO
# 46                                        SEM MOTIVO
# 47                                        SEM MOTIVO
# 48                                        SEM MOTIVO
# 49                                        SEM MOTIVO
# 50                                        SEM MOTIVO
# 51                                        SEM MOTIVO
# 52                                        SEM MOTIVO
# 53                                        SEM MOTIVO
# 54                                        SEM MOTIVO
# 55                                        SEM MOTIVO
# 56                                        SEM MOTIVO
# 57                                        SEM MOTIVO
# 58                                        SEM MOTIVO
# 59                                        SEM MOTIVO
# 60                                        SEM MOTIVO
# 61                                        SEM MOTIVO
# 62                                        SEM MOTIVO
# 63                                        SEM MOTIVO
# 64                                        SEM MOTIVO
# 65                                        SEM MOTIVO
# 66                                        SEM MOTIVO
# 67                                        SEM MOTIVO
# 68                                        SEM MOTIVO
# 69                                        SEM MOTIVO
# 70                                        SEM MOTIVO
# 71                                        SEM MOTIVO
# 72                                        SEM MOTIVO
# 73                                        SEM MOTIVO
# 74                                        SEM MOTIVO
# 75                                        SEM MOTIVO
# 76                                        SEM MOTIVO
# 77                                        SEM MOTIVO
# 78                                        SEM MOTIVO
# 79                                        SEM MOTIVO
# 80                                        SEM MOTIVO
# 81                                        SEM MOTIVO
# 82                                        SEM MOTIVO
# 83                                        SEM MOTIVO
# 84                                        SEM MOTIVO
# 85                                        SEM MOTIVO
# 86                                        SEM MOTIVO
# 87                                        SEM MOTIVO
# 88                                        SEM MOTIVO
# 89                                        SEM MOTIVO
# 90                                        SEM MOTIVO
# 91                                        SEM MOTIVO
# 92                                        SEM MOTIVO
# 93                                        SEM MOTIVO
# 94                                        SEM MOTIVO
# 95                                        SEM MOTIVO
# 96                                        SEM MOTIVO
# 97                                        SEM MOTIVO
# 98                                        SEM MOTIVO
# 99                                        SEM MOTIVO
# 100                                       SEM MOTIVO
# 101                                       SEM MOTIVO
# 102                                       SEM MOTIVO
# 103                                       SEM MOTIVO
# 104                                       SEM MOTIVO
# 105                                       SEM MOTIVO
# 106                                       SEM MOTIVO
# 107                                       SEM MOTIVO
# 108                                       SEM MOTIVO
# 109                                       SEM MOTIVO
# 110                                       SEM MOTIVO
# 111                                       SEM MOTIVO
# 112                                       SEM MOTIVO
# 113                                       SEM MOTIVO
# 114                                       SEM MOTIVO
# 115                                       SEM MOTIVO
# 116                                       SEM MOTIVO
# 117                                       SEM MOTIVO
# 118                                       SEM MOTIVO
# 119                                       SEM MOTIVO
# 120                                       SEM MOTIVO
# 121                                       SEM MOTIVO
# 122                                       SEM MOTIVO
# 123                                       SEM MOTIVO
# 124                                       SEM MOTIVO
# 125                                       SEM MOTIVO
# 126                                       SEM MOTIVO
# 127                                       SEM MOTIVO
# 128                                       SEM MOTIVO
# 129                                       SEM MOTIVO
# 130                                       SEM MOTIVO
# 131                                       SEM MOTIVO
# 132                                       SEM MOTIVO
# 133                                       SEM MOTIVO
# 134                                       SEM MOTIVO
# 135                                       SEM MOTIVO
# 136                                       SEM MOTIVO
# 137                                       SEM MOTIVO
# 138                                       SEM MOTIVO
# 139                                       SEM MOTIVO
# 140                                       SEM MOTIVO
# 141                                       SEM MOTIVO
# 142                                       SEM MOTIVO
# 143                                       SEM MOTIVO
# 144                                       SEM MOTIVO
# 145                                       SEM MOTIVO
# 146                                       SEM MOTIVO
# 147                           OMISSAO DE DECLARACOES
# 148                                       SEM MOTIVO
# 149                                       SEM MOTIVO
# 150                                       SEM MOTIVO
# 151                                       SEM MOTIVO
# 152                                       SEM MOTIVO
# 153                                       SEM MOTIVO
# 154                                       SEM MOTIVO
# 155                                       SEM MOTIVO
# 156                                       SEM MOTIVO
# 157                                       SEM MOTIVO
# 158                                       SEM MOTIVO
# 159                                       SEM MOTIVO
# 160                                       SEM MOTIVO
# 161                                       SEM MOTIVO
# 162                                       SEM MOTIVO
# 163                                       SEM MOTIVO
# 164                                       SEM MOTIVO
# 165                                       SEM MOTIVO
# 166                                       SEM MOTIVO
# 167                                       SEM MOTIVO
# 168                                       SEM MOTIVO
# 169                                       SEM MOTIVO
# 170                                       SEM MOTIVO
# 171                                       SEM MOTIVO
# 172                                       SEM MOTIVO
# 173                                       SEM MOTIVO
# 174                                       SEM MOTIVO
# 175                                       SEM MOTIVO
# 176                                       SEM MOTIVO
# 177                                       SEM MOTIVO
# 178                                       SEM MOTIVO
# 179                                       SEM MOTIVO
# 180                                       SEM MOTIVO
# 181                                       SEM MOTIVO
# 182                                       SEM MOTIVO
# 183                                       SEM MOTIVO
# 184                                       SEM MOTIVO
# 185                                       SEM MOTIVO
# 186                                       SEM MOTIVO
# 187                                       SEM MOTIVO
# 188                           OMISSAO DE DECLARACOES
# 189                                       SEM MOTIVO
# 190                                       SEM MOTIVO
# 191                                       SEM MOTIVO
# 192                                       SEM MOTIVO
# 193                                       SEM MOTIVO
# 194                                       SEM MOTIVO
# 195                                       SEM MOTIVO
# 196                                       SEM MOTIVO
# 197                                       SEM MOTIVO
# 198                                       SEM MOTIVO
# 199                                       SEM MOTIVO
# 200                                       SEM MOTIVO
# 201                                       SEM MOTIVO
# 202                                       SEM MOTIVO
# 203                                       SEM MOTIVO
# 204                                       SEM MOTIVO
# 205                                       SEM MOTIVO
# 206                                       SEM MOTIVO
# 207                                       SEM MOTIVO
# 208                                       SEM MOTIVO
# 209                                       SEM MOTIVO
# 210                                       SEM MOTIVO
# 211                                       SEM MOTIVO
# 212                                       SEM MOTIVO
# 213                                       SEM MOTIVO
# 214                                       SEM MOTIVO
# 215                                       SEM MOTIVO
# 216                                       SEM MOTIVO
# 217                                       SEM MOTIVO
# 218                                       SEM MOTIVO
# 219                                       SEM MOTIVO
# 220                                       SEM MOTIVO
# 221                                       SEM MOTIVO
# 222                                       SEM MOTIVO
# 223                                       SEM MOTIVO
# 224                                       SEM MOTIVO
# 225                                       SEM MOTIVO
# 226                                       SEM MOTIVO
# 227                                       SEM MOTIVO
# 228                                       SEM MOTIVO
# 229                                       SEM MOTIVO
# 230                                       SEM MOTIVO
# 231                                       SEM MOTIVO
# 232                                       SEM MOTIVO
# 233                                       SEM MOTIVO
# 234                                       SEM MOTIVO
# 235                                       SEM MOTIVO
# 236                                       SEM MOTIVO
#
#     descricao_situacao_cadastral
# 0                          ATIVA
# 1                          ATIVA
# 2                          ATIVA
# 3                          ATIVA
# 4                          ATIVA
# 5                          ATIVA
# 6                          ATIVA
# 7                          ATIVA
# 8                          ATIVA
# 9                          ATIVA
# 10                         ATIVA
# 11                         ATIVA
# 12                         ATIVA
# 13                         ATIVA
# 14                         ATIVA
# 15                         ATIVA
# 16                         ATIVA
# 17                         ATIVA
# 18                         ATIVA
# 19                         ATIVA
# 20                         ATIVA
# 21                         ATIVA
# 22                         ATIVA
# 23                         ATIVA
# 24                       BAIXADA
# 25                         ATIVA
# 26                         ATIVA
# 27                         ATIVA
# 28                         ATIVA
# 29                         ATIVA
# 30                         ATIVA
# 31                         ATIVA
# 32                         ATIVA
# 33                         ATIVA
# 34                         ATIVA
# 35                         ATIVA
# 36                         ATIVA
# 37                         ATIVA
# 38                         ATIVA
# 39                         ATIVA
# 40                         ATIVA
# 41                         ATIVA
# 42                         ATIVA
# 43                         ATIVA
# 44                         ATIVA
# 45                         ATIVA
# 46                         ATIVA
# 47                         ATIVA
# 48                         ATIVA
# 49                         ATIVA
# 50                         ATIVA
# 51                         ATIVA
# 52                         ATIVA
# 53                         ATIVA
# 54                         ATIVA
# 55                         ATIVA
# 56                         ATIVA
# 57                         ATIVA
# 58                         ATIVA
# 59                         ATIVA
# 60                         ATIVA
# 61                         ATIVA
# 62                         ATIVA
# 63                         ATIVA
# 64                         ATIVA
# 65                         ATIVA
# 66                         ATIVA
# 67                         ATIVA
# 68                         ATIVA
# 69                         ATIVA
# 70                         ATIVA
# 71                         ATIVA
# 72                         ATIVA
# 73                         ATIVA
# 74                         ATIVA
# 75                         ATIVA
# 76                         ATIVA
# 77                         ATIVA
# 78                         ATIVA
# 79                         ATIVA
# 80                         ATIVA
# 81                         ATIVA
# 82                         ATIVA
# 83                         ATIVA
# 84                         ATIVA
# 85                         ATIVA
# 86                         ATIVA
# 87                         ATIVA
# 88                         ATIVA
# 89                         ATIVA
# 90                         ATIVA
# 91                         ATIVA
# 92                         ATIVA
# 93                         ATIVA
# 94                         ATIVA
# 95                         ATIVA
# 96                         ATIVA
# 97                         ATIVA
# 98                         ATIVA
# 99                         ATIVA
# 100                        ATIVA
# 101                        ATIVA
# 102                        ATIVA
# 103                        ATIVA
# 104                        ATIVA
# 105                        ATIVA
# 106                        ATIVA
# 107                        ATIVA
# 108                        ATIVA
# 109                        ATIVA
# 110                        ATIVA
# 111                        ATIVA
# 112                        ATIVA
# 113                        ATIVA
# 114                        ATIVA
# 115                        ATIVA
# 116                        ATIVA
# 117                        ATIVA
# 118                        ATIVA
# 119                        ATIVA
# 120                        ATIVA
# 121                        ATIVA
# 122                        ATIVA
# 123                        ATIVA
# 124                        ATIVA
# 125                        ATIVA
# 126                        ATIVA
# 127                        ATIVA
# 128                        ATIVA
# 129                        ATIVA
# 130                        ATIVA
# 131                        ATIVA
# 132                        ATIVA
# 133                        ATIVA
# 134                        ATIVA
# 135                        ATIVA
# 136                        ATIVA
# 137                        ATIVA
# 138                        ATIVA
# 139                        ATIVA
# 140                        ATIVA
# 141                        ATIVA
# 142                        ATIVA
# 143                        ATIVA
# 144                        ATIVA
# 145                        ATIVA
# 146                        ATIVA
# 147                       INAPTA
# 148                        ATIVA
# 149                        ATIVA
# 150                        ATIVA
# 151                        ATIVA
# 152                        ATIVA
# 153                        ATIVA
# 154                        ATIVA
# 155                        ATIVA
# 156                        ATIVA
# 157                        ATIVA
# 158                        ATIVA
# 159                        ATIVA
# 160                        ATIVA
# 161                        ATIVA
# 162                        ATIVA
# 163                        ATIVA
# 164                        ATIVA
# 165                        ATIVA
# 166                        ATIVA
# 167                        ATIVA
# 168                        ATIVA
# 169                        ATIVA
# 170                        ATIVA
# 171                        ATIVA
# 172                        ATIVA
# 173                        ATIVA
# 174                        ATIVA
# 175                        ATIVA
# 176                        ATIVA
# 177                        ATIVA
# 178                        ATIVA
# 179                        ATIVA
# 180                        ATIVA
# 181                        ATIVA
# 182                        ATIVA
# 183                        ATIVA
# 184                        ATIVA
# 185                        ATIVA
# 186                        ATIVA
# 187                        ATIVA
# 188                       INAPTA
# 189                        ATIVA
# 190                        ATIVA
# 191                        ATIVA
# 192                        ATIVA
# 193                        ATIVA
# 194                        ATIVA
# 195                        ATIVA
# 196                        ATIVA
# 197                        ATIVA
# 198                        ATIVA
# 199                        ATIVA
# 200                        ATIVA
# 201                        ATIVA
# 202                        ATIVA
# 203                        ATIVA
# 204                        ATIVA
# 205                        ATIVA
# 206                        ATIVA
# 207                        ATIVA
# 208                        ATIVA
# 209                        ATIVA
# 210                        ATIVA
# 211                        ATIVA
# 212                        ATIVA
# 213                        ATIVA
# 214                        ATIVA
# 215                        ATIVA
# 216                        ATIVA
# 217                        ATIVA
# 218                        ATIVA
# 219                        ATIVA
# 220                        ATIVA
# 221                        ATIVA
# 222                        ATIVA
# 223                        ATIVA
# 224                        ATIVA
# 225                        ATIVA
# 226                        ATIVA
# 227                        ATIVA
# 228                        ATIVA
# 229                        ATIVA
# 230                        ATIVA
# 231                        ATIVA
# 232                        ATIVA
# 233                        ATIVA
# 234                        ATIVA
# 235                        ATIVA
# 236                        ATIVA
